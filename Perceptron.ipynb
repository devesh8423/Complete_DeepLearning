# %% [markdown]
# <a href="https://colab.research.google.com/github/devesh8423/Complete_DeepLearning/blob/main/Perceptron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/placement.csv")
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
sns.scatterplot(x="cgpa",y="resume_score",hue="placed",data=df); # Sort Of Linear Data

# %% [markdown]
# # Draw Back of Perceptron is Not good performance on Non  Linear Data

# %%
x=df.iloc[:,:-1]
x
# Out:
#     cgpa  resume_score
# 0   8.14          6.52
# 1   6.17          5.17
# 2   8.27          8.86
# 3   6.88          7.27
# 4   7.52          7.30
# ..   ...           ...
# 95  6.33          6.38
# 96  8.23          7.76
# 97  6.65          7.78
# 98  8.14          5.63
# 99  6.09          6.61
#
# [100 rows x 2 columns]

# %%
y=df.iloc[:,-1]
y
# Out:
# 0     1
# 1     0
# 2     1
# 3     1
# 4     1
#      ..
# 95    0
# 96    1
# 97    0
# 98    1
# 99    0
# Name: placed, Length: 100, dtype: int64

# %%
from sklearn.linear_model import Perceptron

# %%
p=Perceptron()
p.fit(x,y)
# Out:
# Perceptron()

# %%
p.coef_
# Out:
# array([[ 40.26, -36.  ]])

# %%
p.intercept_
# Out:
# array([-25.])

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x.values,y.values,clf=p,legend=2);
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(

# %%
and_df=pd.DataFrame()
or_df=pd.DataFrame()
Exor_df=pd.DataFrame()

# %%
and_df["x1"]=[0,0,1,1]
and_df["x2"]=[0,1,0,1]
and_df["y"]=[0,0,0,1]

# %%
and_df
# Out:
#    x1  x2  y
# 0   0   0  0
# 1   0   1  0
# 2   1   0  0
# 3   1   1  1

# %%
or_df["x1"]=[0,0,1,1]
or_df["x2"]=[0,1,0,1]
or_df["y"]=[0,1,1,1]

# %%
or_df
# Out:
#    x1  x2  y
# 0   0   0  0
# 1   0   1  1
# 2   1   0  1
# 3   1   1  1

# %%
Exor_df["x1"]=[0,0,1,1]
Exor_df["x2"]=[0,1,0,1]
Exor_df["y"]=[0,1,1,0]

# %%
Exor_df
# Out:
#    x1  x2  y
# 0   0   0  0
# 1   0   1  1
# 2   1   0  1
# 3   1   1  0

# %% [markdown]
# ### AND GRAPH AND PREDICTION USING PERCEPTRON

# %%
sns.scatterplot(x="x1",y="x2",hue="y",data=and_df);

# %%
x_and=and_df.iloc[:,:-1]
y_and=and_df.iloc[:,-1]

# %%
from sklearn.linear_model import Perceptron

# %%
p=Perceptron()
p.fit(x_and,y_and)
# Out:
# Perceptron()

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_and.values,y_and.values,clf=p,legend=2);
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(

# %% [markdown]
# OR GRAPH AND PREDICTION USING PERCEPTRON

# %%
or_df
# Out:
#    x1  x2  y
# 0   0   0  0
# 1   0   1  1
# 2   1   0  1
# 3   1   1  1

# %%
sns.scatterplot(x="x1",y="x2",hue="y",data=or_df);

# %%
from mlxtend.plotting import plot_decision_regions

# %%
x_or=or_df.iloc[:,:-1]
y_or=or_df.iloc[:,-1]

# %%
p=Perceptron()
p.fit(x_or,y_or)
# Out:
# Perceptron()

# %%
plot_decision_regions(x_or.values,y_or.values,clf=p,legend=2);
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(

# %%
#

# %% [markdown]
# EXOR GRAPH AND PREDICTION USING PERCEPTRON

# %%
Exor_df
# Out:
#    x1  x2  y
# 0   0   0  0
# 1   0   1  1
# 2   1   0  1
# 3   1   1  0

# %%
sns.scatterplot(x="x1",y="x2",hue="y",data=Exor_df);

# %%
x_exor=Exor_df.iloc[:,:-1]
y_exor=Exor_df.iloc[:,-1]

# %%
p=Perceptron()
p.fit(x_exor,y_exor)
# Out:
# Perceptron()

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_exor.values,y_exor.values,clf=p,legend=2);
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(

# %%
# HEnce Prroved THAT IT DOES NOT PERFROM ON NON_LINEARDATA
