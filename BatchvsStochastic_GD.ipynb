# %% [markdown]
# <a href="https://colab.research.google.com/github/devesh8423/Complete_DeepLearning/blob/main/BatchvsStochastic_GD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("/content/Social_Network_Ads.csv")
df
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
df.head(3)
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0

# %%
df["Gender"]=np.where(df["Gender"]=="Male",1,0)

# %%
df=df[["Gender","Age","EstimatedSalary","Purchased"]]

# %%
df
# Out:
#      Gender  Age  EstimatedSalary  Purchased
# 0         1   19            19000          0
# 1         1   35            20000          0
# 2         0   26            43000          0
# 3         0   27            57000          0
# 4         1   19            76000          0
# ..      ...  ...              ...        ...
# 395       0   46            41000          1
# 396       1   51            23000          1
# 397       0   50            20000          1
# 398       1   36            33000          0
# 399       0   49            36000          1
#
# [400 rows x 4 columns]

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_scaled=sc.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.2,random_state=42)

# %%
import tensorflow
from tensorflow import keras
from keras import Sequential
from keras.layers  import Dense

# %%
model=Sequential()
model.add(Dense(10,activation="relu",input_dim=3))
model.add(Dense(10,activation="relu"))
model.add(Dense(1,activation="sigmoid"))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 10)             │            40 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 10)             │           110 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 161 (644.00 B)
#  Trainable params: 161 (644.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #**StochasticGD Beacuse here batch_Size=1**

# %%
import time
model.compile(loss="binary_crossentropy",metrics=["accuracy"])
start=time.time()
history=model.fit(x_scaled,y,epochs=500,batch_size=1,validation_split=0.2)
print(time.time()-start)
# Out:
# Epoch 1/500
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6907 - loss: 0.6253 - val_accuracy: 0.3625 - val_loss: 0.7903
# Epoch 2/500
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7295 - loss: 0.4696 - val_accuracy: 0.4375 - val_loss: 0.7181
# Epoch 3/500
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7389 - loss: 0.4164 - val_accuracy: 0.6750 - val_loss: 0.5965
# Epoch 4/500
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7676 - loss: 0.3933 - val_accuracy: 0.7125 - val_loss: 0.5222
# Epoch 5/500
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8326 - loss: 0.3444 - val_accuracy: 0.8000 - val_loss: 0.4304
# Epoch 6/500
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8851 - loss: 0.2455 - val_accuracy: 0.8500 - val_loss: 0.3744
# Epoch 7/500
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8518 - loss: 0.2859 - val_accuracy: 0.9000 - val_loss: 0.3282
# Epoch 8/500
# ...

# %% [markdown]
# #**batchGD beacuse batch size=350**

# %%
import time
model.compile(loss="binary_crossentropy",metrics=["accuracy"])
start=time.time()
history=model.fit(x_scaled,y,epochs=500,batch_size=x_train.shape[0],validation_split=0.2)
print(time.time()-start)
# Out:
# Epoch 1/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.9094 - loss: 0.2613 - val_accuracy: 0.8875 - val_loss: 0.2641
# Epoch 2/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9094 - loss: 0.2524 - val_accuracy: 0.8875 - val_loss: 0.2582
# Epoch 3/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.9094 - loss: 0.2472 - val_accuracy: 0.8875 - val_loss: 0.2534
# Epoch 4/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9094 - loss: 0.2434 - val_accuracy: 0.8875 - val_loss: 0.2512
# Epoch 5/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9062 - loss: 0.2403 - val_accuracy: 0.8875 - val_loss: 0.2483
# Epoch 6/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9062 - loss: 0.2376 - val_accuracy: 0.8875 - val_loss: 0.2485
# Epoch 7/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9062 - loss: 0.2353 - val_accuracy: 0.8875 - val_loss: 0.2471
# Epoch 8/500
# ...

# %% [markdown]
# #**MiniBatchGD By default system use here no need to manuly write batch_size**

# %%
import time
model.compile(loss="binary_crossentropy",metrics=["accuracy"])
start=time.time()
history=model.fit(x_scaled,y,epochs=500,validation_split=0.2)
print(time.time()-start)
# Out:
# Epoch 1/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9221 - loss: 0.1866 - val_accuracy: 0.9000 - val_loss: 0.2849
# Epoch 2/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9410 - loss: 0.1427 - val_accuracy: 0.9000 - val_loss: 0.2981
# Epoch 3/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8871 - loss: 0.2160 - val_accuracy: 0.9000 - val_loss: 0.2958
# Epoch 4/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9135 - loss: 0.2071 - val_accuracy: 0.9000 - val_loss: 0.2877
# Epoch 5/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9039 - loss: 0.1717 - val_accuracy: 0.9000 - val_loss: 0.3019
# Epoch 6/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9103 - loss: 0.1741 - val_accuracy: 0.9000 - val_loss: 0.3008
# Epoch 7/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9173 - loss: 0.2093 - val_accuracy: 0.9000 - val_loss: 0.2981
# Epoch 8/500
# ...
